# %% [markdown]
# <a href="https://colab.research.google.com/github/PriyansuSonu/Priyansu-/blob/main/P3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#PANDAS - Python library, which is used to create DATAFRAME and series
##dataframe - tabled data(data in form of table)
#series - column

# %%
mydataset = {'cars':['BMW','Volvo','Ford'],'passings':[3,7,2]}
mydataset
type(mydataset)
# Out:
# dict

# %%
import pandas as pd
df=pd.DataFrame(mydataset)
df
# Out:
#     cars  passings
# 0    BMW         3
# 1  Volvo         7
# 2   Ford         2

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
a=[1,7,2,6]
myvar=pd.Series(a)
myvar
# Out:
# 0    1
# 1    7
# 2    2
# 3    6
# dtype: int64

# %%
#using pandas we can easily change the index
a=[1,7,2,6]
myvar1=pd.Series(a,index=['w','x','y','z'])
myvar1
# Out:
# w    1
# x    7
# y    2
# z    6
# dtype: int64

# %%
sports1=pd.Series([1,2,3,4],index=['Cricket','Football','hockey','Golf'])
sports1
# Out:
# Cricket     1
# Football    2
# hockey      3
# Golf        4
# dtype: int64

# %%
sports2=pd.Series([1,2,5,4],index=['Cricket','basketball','baseball','golf'])
sports2
# Out:
# Cricket       1
# basketball    2
# baseball      5
# golf          4
# dtype: int64

# %%
s=sports1 + sports2
s
# Out:
# Cricket       2.0
# Football      NaN
# Golf          NaN
# baseball      NaN
# basketball    NaN
# golf          NaN
# hockey        NaN
# dtype: float64

# %%
#nan - Not a number(null value/missing values)
#whenever nan comes into picture, int is vonvertedd to float

# %%
s.dropna()#let us drop all the null values
# Out:
# Cricket    2.0
# dtype: float64

# %%
#now let us replace the nan values with a number
s.fillna(value=1)
# Out:
# Cricket       2.0
# Football      1.0
# Golf          1.0
# baseball      1.0
# basketball    1.0
# golf          1.0
# hockey        1.0
# dtype: float64

# %%
s
# Out:
# Cricket       2.0
# Football      NaN
# Golf          NaN
# baseball      NaN
# basketball    NaN
# golf          NaN
# hockey        NaN
# dtype: float64

# %%
#Exploratory Data Analysis - EDA(PRE MACHINE LEARNING)
#EDA - WE FIND DIFFERENT INSIGHTS, WE COME TO DIFFERENT CONCLUSION AND EXPLORE OUR DATA)

# %%
#DATAFRAME - Tabled data
#dataset - is raw unprocessed data in form of rows ADN COLUMNS

# %%
from pandas.core.groupby.groupby import DataFrame
#Dataset - https://storage.googleapis.com/kagglesdsdata/datasets/9590/13660/fruit_data_with_colors.txt?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20230103%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20230103T143706Z&X-Goog-Expires=259200&X-Goog-SignedHeaders=host&X-Goog-Signature=...
#1. Take the Data and create DataFrame
import pandas as pd
df = pd.read_csv('https://storage.googleapis.com/kagglesdsdata/datasets/9590/13660/fruit_data_with_colors.txt?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20230103%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20230103T143706Z&X-Goog-Expires=259200&X-Goog-SignedHeaders=host&X-Goog-Signature=...')
df
# Out:
#    fruit_label\tfruit_name\tfruit_subtype\tmass\twidth\theight\tcolor_score
# 0         1\tapple\tgranny_smith\t192\t8.4\t7.3\t0.55
# 1         1\tapple\tgranny_smith\t180\t8.0\t6.8\t0.59
# 2         1\tapple\tgranny_smith\t176\t7.4\t7.2\t0.60
# 3          2\tmandarin\tmandarin\t86 \t6.2\t4.7\t0.80
# 4          2\tmandarin\tmandarin\t84 \t6.0\t4.6\t0.79
# 5          2\tmandarin\tmandarin\t80 \t5.8\t4.3\t0.77
# 6         2\tmandarin\tmandarin\t80 \t5.9 \t4.3\t0.81
# 7           2\tmandarin\tmandarin\t76\t5.8\t4.0\t0.81
# 8             1\tapple\tbraeburn\t178\t7.1\t7.8\t0.92
# 9             1\tapple\tbraeburn\t172\t7.4\t7.0\t0.89
# 10            1\tapple\tbraeburn\t166\t6.9\t7.3\t0.93
# 11            1\tapple\tbraeburn\t172\t7.1\t7.6\t0.92
# 12            1\tapple\tbraeburn\t154\t7.0\t7.1\t0.88
# 13    1\tapple\tgolden_delicious\t164\t7.3\t7.7\t0.70
# 14    1\tapple\tgolden_delicious\t152\t7.6\t7.3\t0.69
# 15    1\tapple\tgolden_delicious\t156\t7.7\t7.1\t0.69
# 16    1\tapple\tgolden_delicious\t156\t7.6\t7.5\t0.67
# 17    1\tapple\tgolden_delicious\t168\t7.5\t7.6\t0.73
# 18         1\tapple\tcripps_pink\t162\t7.5\t7.1\t0.83
# 19         1\tapple\tcripps_pink\t162\t7.4\t7.2\t0.85
# 20         1\tapple\tcripps_pink\t160\t7.5\t7.5\t0.86
# 21         1\tapple\tcripps_pink\t156\t7.4\t7.4\t0.84
# 22         1\tapple\tcripps_pink\t140\t7.3\t7.1\t0.87
# 23         1\tapple\tcripps_pink\t170\t7.6\t7.9\t0.88
# 24      3\torange\tspanish_jumbo\t342\t9.0\t9.4\t0.75
# 25      3\torange\tspanish_jumbo\t356\t9.2\t9.2\t0.75
# 26      3\torange\tspanish_jumbo\t362\t9.6\t9.2\t0.74
# 27   3\torange\tselected_seconds\t204\t7.5\t9.2\t0.77
# 28   3\torange\tselected_seconds\t140\t6.7\t7.1\t0.72
# 29   3\torange\tselected_seconds\t160\t7.0\t7.4\t0.81
# 30   3\torange\tselected_seconds\t158\t7.1\t7.5\t0.79
# 31   3\torange\tselected_seconds\t210\t7.8\t8.0\t0.82
# 32   3\torange\tselected_seconds\t164\t7.2\t7.0\t0.80
# 33       3\torange\tturkey_navel\t190\t7.5\t8.1\t0.74
# 34       3\torange\tturkey_navel\t142\t7.6\t7.8\t0.75
# 35       3\torange\tturkey_navel\t150\t7.1\t7.9\t0.75
# 36       3\torange\tturkey_navel\t160\t7.1\t7.6\t0.76
# 37       3\torange\tturkey_navel\t154\t7.3\t7.3\t0.79
# 38       3\torange\tturkey_navel\t158\t7.2\t7.8\t0.77
# 39       3\torange\tturkey_navel\t144\t6.8\t7.4\t0.75
# 40       3\torange\tturkey_navel\t154\t7.1\t7.5\t0.78
# 41       3\torange\tturkey_navel\t180\t7.6\t8.2\t0.79
# 42       3\torange\tturkey_navel\t154\t7.2\t7.2\t0.82
# 43     4\tlemon\tspanish_belsan\t194\t7.2\t10.3\t0.70
# 44     4\tlemon\tspanish_belsan\t200\t7.3\t10.5\t0.72
# 45      4\tlemon\tspanish_belsan\t186\t7.2\t9.2\t0.72
# 46     4\tlemon\tspanish_belsan\t216\t7.3\t10.2\t0.71
# 47      4\tlemon\tspanish_belsan\t196\t7.3\t9.7\t0.72
# 48     4\tlemon\tspanish_belsan\t174\t7.3\t10.1\t0.72
# 49             4\tlemon\tunknown\t132\t5.8\t8.7\t0.73
# 50             4\tlemon\tunknown\t130\t6.0\t8.2\t0.71
# 51             4\tlemon\tunknown\t116\t6.0\t7.5\t0.72
# 52             4\tlemon\tunknown\t118\t5.9\t8.0\t0.72
# 53             4\tlemon\tunknown\t120\t6.0\t8.4\t0.74
# 54             4\tlemon\tunknown\t116\t6.1\t8.5\t0.71
# 55             4\tlemon\tunknown\t116\t6.3\t7.7\t0.72
# 56             4\tlemon\tunknown\t116\t5.9\t8.1\t0.73
# 57             4\tlemon\tunknown\t152\t6.5\t8.5\t0.72
# 58             4\tlemon\tunknown\t118\t6.1\t8.1\t0.70

# %%
import pandas as pd
df = pd.read_csv('/content/fruit_data_with_colors.txt',sep = '\t')
df
# Out:
#     fruit_label fruit_name     fruit_subtype  mass  width  height  color_score
# 0             1      apple      granny_smith   192    8.4     7.3         0.55
# 1             1      apple      granny_smith   180    8.0     6.8         0.59
# 2             1      apple      granny_smith   176    7.4     7.2         0.60
# 3             2   mandarin          mandarin    86    6.2     4.7         0.80
# 4             2   mandarin          mandarin    84    6.0     4.6         0.79
# 5             2   mandarin          mandarin    80    5.8     4.3         0.77
# 6             2   mandarin          mandarin    80    5.9     4.3         0.81
# 7             2   mandarin          mandarin    76    5.8     4.0         0.81
# 8             1      apple          braeburn   178    7.1     7.8         0.92
# 9             1      apple          braeburn   172    7.4     7.0         0.89
# 10            1      apple          braeburn   166    6.9     7.3         0.93
# 11            1      apple          braeburn   172    7.1     7.6         0.92
# 12            1      apple          braeburn   154    7.0     7.1         0.88
# 13            1      apple  golden_delicious   164    7.3     7.7         0.70
# 14            1      apple  golden_delicious   152    7.6     7.3         0.69
# 15            1      apple  golden_delicious   156    7.7     7.1         0.69
# 16            1      apple  golden_delicious   156    7.6     7.5         0.67
# 17            1      apple  golden_delicious   168    7.5     7.6         0.73
# 18            1      apple       cripps_pink   162    7.5     7.1         0.83
# 19            1      apple       cripps_pink   162    7.4     7.2         0.85
# 20            1      apple       cripps_pink   160    7.5     7.5         0.86
# 21            1      apple       cripps_pink   156    7.4     7.4         0.84
# 22            1      apple       cripps_pink   140    7.3     7.1         0.87
# 23            1      apple       cripps_pink   170    7.6     7.9         0.88
# 24            3     orange     spanish_jumbo   342    9.0     9.4         0.75
# 25            3     orange     spanish_jumbo   356    9.2     9.2         0.75
# 26            3     orange     spanish_jumbo   362    9.6     9.2         0.74
# 27            3     orange  selected_seconds   204    7.5     9.2         0.77
# 28            3     orange  selected_seconds   140    6.7     7.1         0.72
# 29            3     orange  selected_seconds   160    7.0     7.4         0.81
# 30            3     orange  selected_seconds   158    7.1     7.5         0.79
# 31            3     orange  selected_seconds   210    7.8     8.0         0.82
# 32            3     orange  selected_seconds   164    7.2     7.0         0.80
# 33            3     orange      turkey_navel   190    7.5     8.1         0.74
# 34            3     orange      turkey_navel   142    7.6     7.8         0.75
# 35            3     orange      turkey_navel   150    7.1     7.9         0.75
# 36            3     orange      turkey_navel   160    7.1     7.6         0.76
# 37            3     orange      turkey_navel   154    7.3     7.3         0.79
# 38            3     orange      turkey_navel   158    7.2     7.8         0.77
# 39            3     orange      turkey_navel   144    6.8     7.4         0.75
# 40            3     orange      turkey_navel   154    7.1     7.5         0.78
# 41            3     orange      turkey_navel   180    7.6     8.2         0.79
# 42            3     orange      turkey_navel   154    7.2     7.2         0.82
# 43            4      lemon    spanish_belsan   194    7.2    10.3         0.70
# 44            4      lemon    spanish_belsan   200    7.3    10.5         0.72
# 45            4      lemon    spanish_belsan   186    7.2     9.2         0.72
# 46            4      lemon    spanish_belsan   216    7.3    10.2         0.71
# 47            4      lemon    spanish_belsan   196    7.3     9.7         0.72
# 48            4      lemon    spanish_belsan   174    7.3    10.1         0.72
# 49            4      lemon           unknown   132    5.8     8.7         0.73
# 50            4      lemon           unknown   130    6.0     8.2         0.71
# 51            4      lemon           unknown   116    6.0     7.5         0.72
# 52            4      lemon           unknown   118    5.9     8.0         0.72
# 53            4      lemon           unknown   120    6.0     8.4         0.74
# 54            4      lemon           unknown   116    6.1     8.5         0.71
# 55            4      lemon           unknown   116    6.3     7.7         0.72
# 56            4      lemon           unknown   116    5.9     8.1         0.73
# 57            4      lemon           unknown   152    6.5     8.5         0.72
# 58            4      lemon           unknown   118    6.1     8.1         0.70

# %%
df. shape #(59,7) - 59 rows,7 column
# Out:
# (59, 7)

# %%
df.size #Total no. of element in dataframe
# Out:
# 413

# %%
df.info #it gives the information  about the dataframe

# %%
#Slicing
#Slice row indexes from 25 to 43
#var[inclusive:exclusive]
df[25:44] #25 is inclusive and 44 is exclusive
# Out:
#     fruit_label fruit_name     fruit_subtype  mass  width  height  color_score
# 25            3     orange     spanish_jumbo   356    9.2     9.2         0.75
# 26            3     orange     spanish_jumbo   362    9.6     9.2         0.74
# 27            3     orange  selected_seconds   204    7.5     9.2         0.77
# 28            3     orange  selected_seconds   140    6.7     7.1         0.72
# 29            3     orange  selected_seconds   160    7.0     7.4         0.81
# 30            3     orange  selected_seconds   158    7.1     7.5         0.79
# 31            3     orange  selected_seconds   210    7.8     8.0         0.82
# 32            3     orange  selected_seconds   164    7.2     7.0         0.80
# 33            3     orange      turkey_navel   190    7.5     8.1         0.74
# 34            3     orange      turkey_navel   142    7.6     7.8         0.75
# 35            3     orange      turkey_navel   150    7.1     7.9         0.75
# 36            3     orange      turkey_navel   160    7.1     7.6         0.76
# 37            3     orange      turkey_navel   154    7.3     7.3         0.79
# 38            3     orange      turkey_navel   158    7.2     7.8         0.77
# 39            3     orange      turkey_navel   144    6.8     7.4         0.75
# 40            3     orange      turkey_navel   154    7.1     7.5         0.78
# 41            3     orange      turkey_navel   180    7.6     8.2         0.79
# 42            3     orange      turkey_navel   154    7.2     7.2         0.82
# 43            4      lemon    spanish_belsan   194    7.2    10.3         0.70

# %%
#slicing
#Slice row indexes from 25 to 43 and column indexes 0 to 1
#var.iloc[row slicing ,column slicing]
df.iloc[25:44,0:2]
# Out:
#     fruit_label fruit_name
# 25            3     orange
# 26            3     orange
# 27            3     orange
# 28            3     orange
# 29            3     orange
# 30            3     orange
# 31            3     orange
# 32            3     orange
# 33            3     orange
# 34            3     orange
# 35            3     orange
# 36            3     orange
# 37            3     orange
# 38            3     orange
# 39            3     orange
# 40            3     orange
# 41            3     orange
# 42            3     orange
# 43            4      lemon

# %%
#now i just want to know the no of unique fruits names
df.fruit_name.nunique()
# Out:
# 4

# %%
df['fruit_name'].nunique()
# Out:
# 4

# %%
# i want the unique fruit names
df['fruit_name'].unique()
# Out:
# array(['apple', 'mandarin', 'orange', 'lemon'], dtype=object)

# %%
fname = df.fruit_name.unique()

# %%
fname
# Out:
# array(['apple', 'mandarin', 'orange', 'lemon'], dtype=object)

# %%
#now i want the exact count of each and every fruit
#apples-19
#mandarine-5
#oranges-19
#lemons-16 this count was manually

# %%
fsize=df.groupby('fruit_name').size()
fsize
# Out:
# fruit_name
# apple       19
# lemon       16
# mandarin     5
# orange      19
# dtype: int64

# %%
#visualisation
import matplotlib.pyplot as plt
plt.bar(fname,fsize,color=['red','gold','orange','lime'])
# Out:
# <BarContainer object of 4 artists>
